# %%
import pandas as pd
import seaborn as sns

# %%
wh_all_df = pd.read_excel('WHR20_DataForTable2.1.xls')

# %%
wh_all_df
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
cols_of_interest = wh_all_df.columns[1:8]
wh_withna_df = wh_all_df[cols_of_interest]

# %%
sns.pairplot(wh_withna_df)

# %%
wh_withna_df.isna().sum()
# Out:
# year                                 0
# Life Ladder                          0
# Log GDP per capita                  29
# Social support                      13
# Healthy life expectancy at birth    52
# Freedom to make life choices        31
# Generosity                          83
# dtype: int64

# %%
wh_df = wh_withna_df.dropna()

# %%
rows_2006_to_2018 = wh_df['year'] <= 2018
wh_df.loc[rows_2006_to_2018].drop(['year', 'Life Ladder'], axis=1)
# Out:
#       Log GDP per capita  Social support  Healthy life expectancy at birth  \
# 0               7.144916        0.450662                         50.799999
# 1               7.314788        0.552308                         51.200001
# 2               7.421525        0.539075                         51.599998
# 3               7.394349        0.521104                         51.919998
# 4               7.480296        0.520637                         52.240002
# ...                  ...             ...                               ...
# 1842            7.826639        0.765839                         52.380001
# 1843            7.827643        0.735800                         53.799999
# 1844            7.819675        0.768425                         54.400002
# 1845            7.851042        0.754147                         55.000000
# 1846            7.896704        0.775388                         55.599998
#
#       Freedom to make life choices  Generosity
# ...

# %%
from happypred import whdata_to_csv

# %%
X_train_path, y_train_path, X_test_path, y_test_path = whdata_to_csv('WHR20_DataForTable2.1.xls')

# %%
X_train_path
# Out:
# 'X_train.csv'
